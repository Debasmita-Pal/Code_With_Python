# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Pal/Code_With_Python/blob/main/DL_ASS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Activation Functions

# %%
#REG. NO: 20MAI0018

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-5, 5, 0.01)

def plot(func, yaxis=(-1.4, 1.4)):
    plt.ylim(yaxis)
    plt.locator_params(nbins=5)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.axhline(lw=1, c='black')
    plt.axvline(lw=1, c='black')
    plt.grid(alpha=0.4, ls='-.')
    plt.box(on=None)
    plt.plot(x, func(x), c='r', lw=3)

# %% [markdown]
# Sigmoid Activation Function

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
plot(sigmoid, yaxis=(-0.4, 1.4))

# %% [markdown]
# TanH or Hyperbolic Tangent Activation Function

# %%
def tanh(x):
    return 2 / (1 + np.exp(-2 * x)) -1
plot(tanh)

# %% [markdown]
# Rectified Linear Units(Relu) Activation Function

# %%
relu = np.vectorize(lambda x: x if x > 0 else 0, otypes=[np.float])
plot(relu, yaxis=(-0.4, 1.4))

# %% [markdown]
# Leaky Rectified Linear Units(Leaky ReLU) Activation Function

# %%
leaky_relu = np.vectorize(lambda x: max(0.1 * x, x), otypes=[np.float])
plot(leaky_relu)

# %% [markdown]
# Exponential Linear Units(ELU) Activation Function

# %%
elu = np.vectorize(lambda x: x if x > 0 else 0.5 * (np.exp(x) - 1), otypes=[np.float])
plot(elu)
