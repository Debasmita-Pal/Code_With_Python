# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Pal/Code_With_Python/blob/main/20MAI0018_ASS4_QS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REG NO :20MAI0018

import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
import tensorflow_datasets as tfds

tfds.disable_progress_bar()

train_ds, validation_ds, test_ds = tfds.load(
    "cats_vs_dogs",
    # Reserve 10% for validation and 10% for test
    split=["train[:40%]", "train[40%:50%]", "train[50%:60%]"],
    as_supervised=True,  # Include labels
)

print("Number of training samples: %d" % tf.data.experimental.cardinality(train_ds))
print(
    "Number of validation samples: %d" % tf.data.experimental.cardinality(validation_ds)
)
print("Number of test samples: %d" % tf.data.experimental.cardinality(test_ds))
# Out:
# Number of training samples: 9305
# Number of validation samples: 2326
# Number of test samples: 2326

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(int(label))
    plt.axis("off")

# %%
size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, size), y))

# %%
batch_size = 32

train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=10)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=10)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=10)

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(0.1),
    ]
)

# %%
import numpy as np

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    first_image = images[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(
            tf.expand_dims(first_image, 0), training=True
        )
        plt.imshow(augmented_image[0].numpy().astype("int32"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
base_model = keras.applications.Xception(
    weights="imagenet",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False,
)  # Do not include the ImageNet classifier at the top.

# Freeze the base_model
base_model.trainable = False

# Create new model on top
inputs = keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)  # Apply random data augmentation

# Pre-trained Xception weights requires that input be normalized
# from (0, 255) to a range (-1., +1.), the normalization layer
# does the following, outputs = (inputs - mean) / sqrt(var)
norm_layer = keras.layers.experimental.preprocessing.Normalization()
mean = np.array([127.5] * 3)
var = mean ** 2
# Scale inputs to [-1, +1]
x = norm_layer(x)
norm_layer.set_weights([mean, var])

# The base model contains batchnorm layers. We want to keep them in inference mode
# when we unfreeze the base model for fine-tuning, so we make sure that the
# base_model is running in inference mode here.
x = base_model(x, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
x = keras.layers.Dropout(0.2)(x)  # Regularize with dropout
outputs = keras.layers.Dense(1)(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization_8 (Normalizati (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 2,049
# Non-trainable params: 20,861,487
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 20
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 291/291 [==============================] - 57s 184ms/step - loss: 0.2383 - binary_accuracy: 0.8859 - val_loss: 0.0840 - val_binary_accuracy: 0.9690
# Epoch 2/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1153 - binary_accuracy: 0.9508 - val_loss: 0.0753 - val_binary_accuracy: 0.9712
# Epoch 3/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1201 - binary_accuracy: 0.9491 - val_loss: 0.0787 - val_binary_accuracy: 0.9703
# Epoch 4/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1098 - binary_accuracy: 0.9512 - val_loss: 0.0728 - val_binary_accuracy: 0.9703
# Epoch 5/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1061 - binary_accuracy: 0.9554 - val_loss: 0.0727 - val_binary_accuracy: 0.9708
# Epoch 6/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1031 - binary_accuracy: 0.9572 - val_loss: 0.0718 - val_binary_accuracy: 0.9721
# Epoch 7/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1032 - binary_accuracy: 0.9589 - val_loss: 0.0736 - val_binary_accuracy: 0.9695
# Epoch 8/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0990 - binary_accuracy: 0.9624 - val_loss: 0.0719 - val_binary_accuracy: 0.9716
# Epoch 9/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.1048 - binary_accuracy: 0.9550 - val_loss: 0.0700 - val_binary_accuracy: 0.9712
# Epoch 10/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.0949 - binary_accuracy: 0.9598 - val_loss: 0.0708 - val_binary_accuracy: 0.9733
# Epoch 11/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.1016 - binary_accuracy: 0.9618 - val_loss: 0.0697 - val_binary_accuracy: 0.9729
# Epoch 12/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0934 - binary_accuracy: 0.9621 - val_loss: 0.0717 - val_binary_accuracy: 0.9716
# Epoch 13/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0898 - binary_accuracy: 0.9629 - val_loss: 0.0748 - val_binary_accuracy: 0.9708
# Epoch 14/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0888 - binary_accuracy: 0.9664 - val_loss: 0.0717 - val_binary_accuracy: 0.9712
# Epoch 15/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0947 - binary_accuracy: 0.9605 - val_loss: 0.0708 - val_binary_accuracy: 0.9716
# Epoch 16/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0967 - binary_accuracy: 0.9599 - val_loss: 0.0719 - val_binary_accuracy: 0.9725
# Epoch 17/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0928 - binary_accuracy: 0.9625 - val_loss: 0.0706 - val_binary_accuracy: 0.9725
# Epoch 18/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0910 - binary_accuracy: 0.9676 - val_loss: 0.0740 - val_binary_accuracy: 0.9690
# Epoch 19/20
# 291/291 [==============================] - 52s 180ms/step - loss: 0.0969 - binary_accuracy: 0.9597 - val_loss: 0.0744 - val_binary_accuracy: 0.9699
# Epoch 20/20
# 291/291 [==============================] - 52s 179ms/step - loss: 0.0972 - binary_accuracy: 0.9590 - val_loss: 0.0771 - val_binary_accuracy: 0.9699

# %%
base_model.trainable = True
model.summary()

model.compile(
    optimizer=keras.optimizers.Adam(1e-5),  # Low learning rate
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()],
)

epochs = 10
model.fit(train_ds, epochs=epochs, validation_data=validation_ds)
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 150, 150, 3)       0
# _________________________________________________________________
# normalization_8 (Normalizati (None, 150, 150, 3)       7
# _________________________________________________________________
# xception (Functional)        (None, 5, 5, 2048)        20861480
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 20,863,536
# Trainable params: 20,809,001
# Non-trainable params: 54,535
# _________________________________________________________________
# Epoch 1/10
# 291/291 [==============================] - 193s 646ms/step - loss: 0.0822 - binary_accuracy: 0.9666 - val_loss: 0.0600 - val_binary_accuracy: 0.9755
# Epoch 2/10
# 291/291 [==============================] - 187s 642ms/step - loss: 0.0509 - binary_accuracy: 0.9799 - val_loss: 0.0550 - val_binary_accuracy: 0.9789
# Epoch 3/10
# 291/291 [==============================] - 187s 642ms/step - loss: 0.0540 - binary_accuracy: 0.9811 - val_loss: 0.0538 - val_binary_accuracy: 0.9794
# Epoch 4/10
# 291/291 [==============================] - 187s 643ms/step - loss: 0.0383 - binary_accuracy: 0.9877 - val_loss: 0.0533 - val_binary_accuracy: 0.9802
# Epoch 5/10
# 291/291 [==============================] - 187s 643ms/step - loss: 0.0276 - binary_accuracy: 0.9889 - val_loss: 0.0523 - val_binary_accuracy: 0.9832
# Epoch 6/10
# 291/291 [==============================] - 188s 645ms/step - loss: 0.0238 - binary_accuracy: 0.9902 - val_loss: 0.0526 - val_binary_accuracy: 0.9819
# Epoch 7/10
# 291/291 [==============================] - 187s 643ms/step - loss: 0.0183 - binary_accuracy: 0.9935 - val_loss: 0.0523 - val_binary_accuracy: 0.9789
# Epoch 8/10
# 291/291 [==============================] - 188s 645ms/step - loss: 0.0165 - binary_accuracy: 0.9930 - val_loss: 0.0684 - val_binary_accuracy: 0.9781
# Epoch 9/10
# 291/291 [==============================] - 188s 645ms/step - loss: 0.0109 - binary_accuracy: 0.9960 - val_loss: 0.0563 - val_binary_accuracy: 0.9824
# Epoch 10/10
# 291/291 [==============================] - 188s 645ms/step - loss: 0.0131 - binary_accuracy: 0.9946 - val_loss: 0.0611 - val_binary_accuracy: 0.9815
