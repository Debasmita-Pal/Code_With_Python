# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Pal/Code_With_Python/blob/main/20MAI0018_DL_ASS3_QS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REG NO: 20MAI0018


#Importing library
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np

np.random.seed(1000)

#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer
AlexNet.add(Conv2D(filters=96, input_shape=(32,32,3), kernel_size=(11,11), strides=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())
# 1st Fully Connected Layer
AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
# Add Dropout to prevent overfitting
AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
AlexNet.add(Dense(4096))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
AlexNet.add(Dense(1000))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
#Add Dropout
AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(10))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 8, 8, 96)          34944
# _________________________________________________________________
# batch_normalization_58 (Batc (None, 8, 8, 96)          384
# _________________________________________________________________
# activation_63 (Activation)   (None, 8, 8, 96)          0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 96)          0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 4, 4, 256)         614656
# _________________________________________________________________
# batch_normalization_59 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_64 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 2, 2, 384)         885120
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# activation_65 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 2, 2, 384)         1327488
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 2, 2, 384)         1536
# _________________________________________________________________
# activation_66 (Activation)   (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 2, 2, 256)         1024
# _________________________________________________________________
# activation_67 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 4096)              1052672
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_68 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_29 (Dense)             (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 4096)              16384
# _________________________________________________________________
# activation_69 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 4096)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 1000)              4097000
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 1000)              4000
# _________________________________________________________________
# activation_70 (Activation)   (None, 1000)              0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_31 (Dense)             (None, 10)                10010
# _________________________________________________________________
# batch_normalization_66 (Batc (None, 10)                40
# _________________________________________________________________
# activation_71 (Activation)   (None, 10)                0
# =================================================================
# Total params: 25,730,506
# Trainable params: 25,709,350
# Non-trainable params: 21,156
# _________________________________________________________________

# %%
# Compiling the model
AlexNet.compile(loss = keras.losses.categorical_crossentropy, optimizer= 'adam', metrics=['accuracy'])

# %%
from keras.models import Sequential

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization

import matplotlib.pyplot as plt

 

ann = Sequential()

x = Conv2D(filters=96,kernel_size=(11,11),input_shape=(227,227,3))

ann.add(x)

 

x1w = x.get_weights()[0][:,:,0,:]

for i in range(1,26):

      plt.subplot(5,5,i)

      plt.imshow(x1w[:,:,i],interpolation="nearest",cmap="gray")

plt.show()

# %%
#Keras library for CIFAR dataset
from keras.datasets import cifar10
(x_train, y_train),(x_test, y_test)=cifar10.load_data()

#Train-validation-test split
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=.3)

#Dimension of the CIFAR10 dataset
print((x_train.shape,y_train.shape))
print((x_val.shape,y_val.shape))
print((x_test.shape,y_test.shape))
# Out:
# ((35000, 32, 32, 3), (35000, 1))
# ((15000, 32, 32, 3), (15000, 1))
# ((10000, 32, 32, 3), (10000, 1))

# %%
#Onehot Encoding the labels.
from sklearn.utils.multiclass import unique_labels
from keras.utils import to_categorical

#Since we have 10 classes we should expect the shape[1] of y_train,y_val and y_test to change from 1 to 10
y_train=to_categorical(y_train)
y_val=to_categorical(y_val)
y_test=to_categorical(y_test)

#Verifying the dimension after one hot encoding
print((x_train.shape,y_train.shape))
print((x_val.shape,y_val.shape))
print((x_test.shape,y_test.shape))
# Out:
# ((35000, 32, 32, 3), (35000, 10))
# ((15000, 32, 32, 3), (15000, 10))
# ((10000, 32, 32, 3), (10000, 10))

# %%
import cv2
import seaborn as sns; sns.set()

class_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
fig, axes = plt.subplots(ncols=7, nrows=3, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].imshow(x_train[index])
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
#Image Data Augmentation
from keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1 )

val_generator = ImageDataGenerator(rotation_range=2, horizontal_flip=True,zoom_range=.1)

test_generator = ImageDataGenerator(rotation_range=2, horizontal_flip= True,zoom_range=.1)

#Fitting the augmentation defined above to the data
train_generator.fit(x_train)
val_generator.fit(x_val)
test_generator.fit(x_test)

# %%
#Learning Rate Annealer
from keras.callbacks import ReduceLROnPlateau
lrr= ReduceLROnPlateau(   monitor='val_acc',   factor=.01,   patience=3,  min_lr=1e-5)

# %%
#Defining the parameters
batch_size= 100
epochs=50
learn_rate=.001

# %%
#Training the model
AlexNet.fit_generator(train_generator.flow(x_train, y_train, batch_size=batch_size), epochs = epochs, steps_per_epoch = x_train.shape[0]//batch_size, validation_data = val_generator.flow(x_val, y_val, batch_size=batch_size), validation_steps = 2, callbacks = [lrr], verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 350/350 [==============================] - 18s 49ms/step - loss: 1.7959 - accuracy: 0.3545 - val_loss: 1.8503 - val_accuracy: 0.3600
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/50
# 350/350 [==============================] - 16s 46ms/step - loss: 1.4451 - accuracy: 0.4899 - val_loss: 2.1476 - val_accuracy: 0.2950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/50
# 350/350 [==============================] - 16s 47ms/step - loss: 1.3066 - accuracy: 0.5454 - val_loss: 1.8282 - val_accuracy: 0.3900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/50
# 350/350 [==============================] - 17s 47ms/step - loss: 1.1973 - accuracy: 0.5874 - val_loss: 1.7479 - val_accuracy: 0.4000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/50
# 350/350 [==============================] - 16s 47ms/step - loss: 1.1329 - accuracy: 0.6100 - val_loss: 1.2652 - val_accuracy: 0.5550
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/50
# 350/350 [==============================] - 17s 47ms/step - loss: 1.0674 - accuracy: 0.6355 - val_loss: 1.5962 - val_accuracy: 0.4200
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/50
# 350/350 [==============================] - 16s 47ms/step - loss: 1.0089 - accuracy: 0.6558 - val_loss: 1.3929 - val_accuracy: 0.4850
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.9668 - accuracy: 0.6683 - val_loss: 1.5495 - val_accuracy: 0.4900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.9149 - accuracy: 0.6866 - val_loss: 0.9899 - val_accuracy: 0.6700
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/50
# 350/350 [==============================] - 16s 46ms/step - loss: 0.8623 - accuracy: 0.7082 - val_loss: 1.3629 - val_accuracy: 0.5650
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.8409 - accuracy: 0.7140 - val_loss: 1.5128 - val_accuracy: 0.4950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.7920 - accuracy: 0.7299 - val_loss: 1.5151 - val_accuracy: 0.5100
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/50
# 350/350 [==============================] - 16s 47ms/step - loss: 0.7758 - accuracy: 0.7350 - val_loss: 1.1605 - val_accuracy: 0.6000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.7434 - accuracy: 0.7454 - val_loss: 1.2406 - val_accuracy: 0.5950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.7120 - accuracy: 0.7612 - val_loss: 1.3281 - val_accuracy: 0.5750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.6861 - accuracy: 0.7734 - val_loss: 1.3573 - val_accuracy: 0.5850
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/50
# 350/350 [==============================] - 18s 52ms/step - loss: 0.6369 - accuracy: 0.7851 - val_loss: 1.6993 - val_accuracy: 0.4700
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/50
# 350/350 [==============================] - 18s 51ms/step - loss: 0.6310 - accuracy: 0.7881 - val_loss: 1.1014 - val_accuracy: 0.6500
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.6025 - accuracy: 0.7984 - val_loss: 1.1941 - val_accuracy: 0.6100
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.5724 - accuracy: 0.8068 - val_loss: 1.8268 - val_accuracy: 0.5000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.5518 - accuracy: 0.8169 - val_loss: 1.6362 - val_accuracy: 0.4850
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/50
# 350/350 [==============================] - 17s 50ms/step - loss: 0.5201 - accuracy: 0.8292 - val_loss: 1.6989 - val_accuracy: 0.4850
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.5021 - accuracy: 0.8321 - val_loss: 1.4812 - val_accuracy: 0.5500
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.4827 - accuracy: 0.8369 - val_loss: 1.2816 - val_accuracy: 0.5950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.4556 - accuracy: 0.8500 - val_loss: 1.2112 - val_accuracy: 0.5950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.4598 - accuracy: 0.8501 - val_loss: 1.3034 - val_accuracy: 0.6000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.4273 - accuracy: 0.8567 - val_loss: 1.5450 - val_accuracy: 0.5650
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.4016 - accuracy: 0.8658 - val_loss: 1.5977 - val_accuracy: 0.5450
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/50
# 350/350 [==============================] - 18s 50ms/step - loss: 0.3941 - accuracy: 0.8687 - val_loss: 1.4391 - val_accuracy: 0.6000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3846 - accuracy: 0.8730 - val_loss: 1.2797 - val_accuracy: 0.5800
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3524 - accuracy: 0.8859 - val_loss: 1.1056 - val_accuracy: 0.6550
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3623 - accuracy: 0.8798 - val_loss: 1.5471 - val_accuracy: 0.5550
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3365 - accuracy: 0.8907 - val_loss: 1.2317 - val_accuracy: 0.6650
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/50
# 350/350 [==============================] - 17s 47ms/step - loss: 0.3223 - accuracy: 0.8921 - val_loss: 1.9068 - val_accuracy: 0.5200
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3046 - accuracy: 0.9003 - val_loss: 1.5738 - val_accuracy: 0.6150
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.3068 - accuracy: 0.8976 - val_loss: 1.3472 - val_accuracy: 0.5900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2978 - accuracy: 0.9030 - val_loss: 1.4046 - val_accuracy: 0.6250
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2784 - accuracy: 0.9092 - val_loss: 1.2523 - val_accuracy: 0.6400
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2799 - accuracy: 0.9074 - val_loss: 1.2465 - val_accuracy: 0.6350
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2687 - accuracy: 0.9120 - val_loss: 1.5461 - val_accuracy: 0.5450
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2603 - accuracy: 0.9122 - val_loss: 1.4348 - val_accuracy: 0.5950
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2437 - accuracy: 0.9199 - val_loss: 1.1282 - val_accuracy: 0.6900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.2424 - accuracy: 0.9195 - val_loss: 1.3413 - val_accuracy: 0.6000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2186 - accuracy: 0.9296 - val_loss: 1.4245 - val_accuracy: 0.6350
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2348 - accuracy: 0.9211 - val_loss: 1.5953 - val_accuracy: 0.6100
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2158 - accuracy: 0.9278 - val_loss: 1.3352 - val_accuracy: 0.6200
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.2128 - accuracy: 0.9305 - val_loss: 2.0270 - val_accuracy: 0.5000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2150 - accuracy: 0.9271 - val_loss: 1.5465 - val_accuracy: 0.5600
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/50
# 350/350 [==============================] - 17s 48ms/step - loss: 0.2057 - accuracy: 0.9314 - val_loss: 1.5549 - val_accuracy: 0.5900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/50
# 350/350 [==============================] - 17s 49ms/step - loss: 0.1888 - accuracy: 0.9385 - val_loss: 1.2837 - val_accuracy: 0.6550
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %%
#After successful training, we will visualize its performance.

import matplotlib.pyplot as plt
#Plotting the training and validation loss

f,ax=plt.subplots(2,1) #Creates 2 subplots under 1 column

#Assigning the first subplot to graph training loss and validation loss
ax[0].plot(AlexNet.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(AlexNet.history.history['val_loss'],color='r',label='Validation Loss')

#Plotting the training accuracy and validation accuracy
ax[1].plot(AlexNet.history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(AlexNet.history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %%
#Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

#Print Confusion matrix
    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
#Making prediction
y_pred=AlexNet.predict_classes(x_test)
y_true=np.argmax(y_test,axis=1)

#Plotting the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_mtx=confusion_matrix(y_true,y_pred)

class_names=['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Plotting non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes = class_names,title = 'Confusion matrix, without normalization')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Confusion matrix, without normalization

# %%
# Plotting normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=class_names, normalize=True, title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix

# %%
#Classification accuracy
from sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_true, y_pred)
print('Accuracy Score = ', acc_score)
# Out:
# Accuracy Score =  0.6498

# %%
AlexNet.save('model_seq.h5')
