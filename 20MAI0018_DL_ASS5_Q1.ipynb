# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Pal/Code_With_Python/blob/main/20MAI0018_DL_ASS5_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#REG NO: 20MAI0018


import pandas as pd
import numpy as np
import keras
import tensorflow as tf
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
df = pd.read_csv('/content/drive/My Drive/CSV.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB
# None

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_axis(df['Date'], inplace=True)
df.drop(columns=['Open', 'High', 'Low', 'Volume'], inplace=True)

# %%
close_data = df['Close'].values
close_data = close_data.reshape((-1,1))

split_percent = 0.80
split = int(split_percent*len(close_data))

close_train = close_data[:split]
close_test = close_data[split:]

date_train = df['Date'][:split]
date_test = df['Date'][split:]

print(len(close_train))
print(len(close_test))
# Out:
# 201
# 51

# %%
look_back = 15

train_generator = TimeseriesGenerator(close_train, close_train, length=look_back, batch_size=20)     
test_generator = TimeseriesGenerator(close_test, close_test, length=look_back, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

model = Sequential()
model.add(
    LSTM(10,
        activation='relu',
        input_shape=(look_back,1))
)
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

num_epochs = 100
model.fit_generator(train_generator, epochs=num_epochs, verbose=1)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 10/10 [==============================] - 1s 23ms/step - loss: 8.7974
# Epoch 2/100
# 10/10 [==============================] - 0s 23ms/step - loss: 8.0815
# Epoch 3/100
# 10/10 [==============================] - 0s 25ms/step - loss: 1.8856
# Epoch 4/100
# 10/10 [==============================] - 0s 19ms/step - loss: 2.7865
# Epoch 5/100
# 10/10 [==============================] - 0s 23ms/step - loss: 1.9611
# Epoch 6/100
# 10/10 [==============================] - 0s 24ms/step - loss: 1.8551
# Epoch 7/100
# 10/10 [==============================] - 0s 20ms/step - loss: 1.4835
# Epoch 8/100
# 10/10 [==============================] - 0s 23ms/step - loss: 1.1721
# Epoch 9/100
# 10/10 [==============================] - 0s 20ms/step - loss: 1.4626
# Epoch 10/100
# 10/10 [==============================] - 0s 25ms/step - loss: 1.0988
# Epoch 11/100
# 10/10 [==============================] - 0s 21ms/step - loss: 1.0206
# Epoch 12/100
# 10/10 [==============================] - 0s 21ms/step - loss: 1.0832
# Epoch 13/100
# 10/10 [==============================] - 0s 20ms/step - loss: 1.0590
# Epoch 14/100
# 10/10 [==============================] - 0s 24ms/step - loss: 1.1061
# Epoch 15/100
# 10/10 [==============================] - 0s 23ms/step - loss: 1.0423
# Epoch 16/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9419
# Epoch 17/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9160
# Epoch 18/100
# 10/10 [==============================] - 0s 24ms/step - loss: 1.0210
# Epoch 19/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9431
# Epoch 20/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9573
# Epoch 21/100
# 10/10 [==============================] - 0s 24ms/step - loss: 1.0805
# Epoch 22/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.8446
# Epoch 23/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9110
# Epoch 24/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.8455
# Epoch 25/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9628
# Epoch 26/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9521
# Epoch 27/100
# 10/10 [==============================] - 0s 23ms/step - loss: 1.0386
# Epoch 28/100
# 10/10 [==============================] - 0s 22ms/step - loss: 1.0470
# Epoch 29/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9709
# Epoch 30/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9257
# Epoch 31/100
# 10/10 [==============================] - 0s 23ms/step - loss: 1.1045
# Epoch 32/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9207
# Epoch 33/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.7960
# Epoch 34/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.6946
# Epoch 35/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6778
# Epoch 36/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.7678
# Epoch 37/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.7458
# Epoch 38/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.6329
# Epoch 39/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.8332
# Epoch 40/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.6588
# Epoch 41/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.7189
# Epoch 42/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.6538
# Epoch 43/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6473
# Epoch 44/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4885
# Epoch 45/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6394
# Epoch 46/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.6532
# Epoch 47/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.6076
# Epoch 48/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4965
# Epoch 49/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.5808
# Epoch 50/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.6120
# Epoch 51/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4878
# Epoch 52/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5235
# Epoch 53/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.5902
# Epoch 54/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4822
# Epoch 55/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3696
# Epoch 56/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.5829
# Epoch 57/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4490
# Epoch 58/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5027
# Epoch 59/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3439
# Epoch 60/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3873
# Epoch 61/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3212
# Epoch 62/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4456
# Epoch 63/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3625
# Epoch 64/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4182
# Epoch 65/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4713
# Epoch 66/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.5444
# Epoch 67/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4014
# Epoch 68/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3849
# Epoch 69/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.4373
# Epoch 70/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.5232
# Epoch 71/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4215
# Epoch 72/100
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3454
# Epoch 73/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.5107
# Epoch 74/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3976
# Epoch 75/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3849
# Epoch 76/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4402
# Epoch 77/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4380
# Epoch 78/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3929
# Epoch 79/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4603
# Epoch 80/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4067
# Epoch 81/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3975
# Epoch 82/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4733
# Epoch 83/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3788
# Epoch 84/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.4523
# Epoch 85/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3893
# Epoch 86/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3430
# Epoch 87/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4498
# Epoch 88/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.4338
# Epoch 89/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3983
# Epoch 90/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.3988
# Epoch 91/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3924
# Epoch 92/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.4197
# Epoch 93/100
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3585
# Epoch 94/100
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4144
# Epoch 95/100
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2929
# Epoch 96/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4787
# Epoch 97/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.4847
# Epoch 98/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.5692
# Epoch 99/100
# 10/10 [==============================] - 0s 22ms/step - loss: 0.7014
# Epoch 100/100
# 10/10 [==============================] - 0s 21ms/step - loss: 0.3463

# %%
import plotly.graph_objs as go

prediction = model.predict_generator(test_generator)

close_train = close_train.reshape((-1))
close_test = close_test.reshape((-1))
prediction = prediction.reshape((-1))

trace1 = go.Scatter(
    x = date_train,
    y = close_train,
    mode = 'lines',
    name = 'Data'
)
trace2 = go.Scatter(
    x = date_test,
    y = prediction,
    mode = 'lines',
    name = 'Prediction'
)
trace3 = go.Scatter(
    x = date_test,
    y = close_test,
    mode='lines',
    name = 'Ground Truth'
)
layout = go.Layout(
    title = "Google Stock",
    xaxis = {'title' : "Date"},
    yaxis = {'title' : "Close"}
)
fig = go.Figure(data=[trace1, trace2, trace3], layout=layout)
fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1905: UserWarning:
#
# `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b393024f-da2e-4b1c-a4e4-557d6e394c54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b393024f-da2e-4b1c-a4e4-557d6e394c54")) {
#                     Plotly.newPlot(
#                         'b393024f-da2e-4b1c-a4e4-557d6e394c54',
#                         [{"mode": "lines", "name": "Data", "type": "scatter", "x": ["2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00:00", "2020-05-21T00:00:00", "2020-05-22T00:00:00", "2020-05-26T00:00:00", "2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "2020-06-23T00:00:00", "2020-06-24T00:00:00", "2020-06-25T00:00:00", "2020-06-26T00:00:00", "2020-06-29T00:00:00", "2020-06-30T00:00:00", "2020-07-01T00:00:00", "2020-07-02T00:00:00", "2020-07-06T00:00:00", "2020-07-07T00:00:00", "2020-07-08T00:00:00", "2020-07-09T00:00:00", "2020-07-10T00:00:00", "2020-07-13T00:00:00", "2020-07-14T00:00:00", "2020-07-15T00:00:00", "2020-07-16T00:00:00", "2020-07-17T00:00:00", "2020-07-20T00:00:00", "2020-07-21T00:00:00", "2020-07-22T00:00:00", "2020-07-23T00:00:00", "2020-07-24T00:00:00", "2020-07-27T00:00:00", "2020-07-28T00:00:00", "2020-07-29T00:00:00", "2020-07-30T00:00:00", "2020-07-31T00:00:00", "2020-08-03T00:00:00", "2020-08-04T00:00:00", "2020-08-05T00:00:00", "2020-08-06T00:00:00", "2020-08-07T00:00:00", "2020-08-10T00:00:00", "2020-08-11T00:00:00", "2020-08-12T00:00:00", "2020-08-13T00:00:00", "2020-08-14T00:00:00", "2020-08-17T00:00:00", "2020-08-18T00:00:00", "2020-08-19T00:00:00", "2020-08-20T00:00:00", "2020-08-21T00:00:00", "2020-08-24T00:00:00", "2020-08-25T00:00:00", "2020-08-26T00:00:00", "2020-08-27T00:00:00", "2020-08-28T00:00:00", "2020-08-31T00:00:00", "2020-09-01T00:00:00", "2020-09-02T00:00:00", "2020-09-03T00:00:00", "2020-09-04T00:00:00", "2020-09-08T00:00:00", "2020-09-09T00:00:00", "2020-09-10T00:00:00", "2020-09-11T00:00:00", "2020-09-14T00:00:00", "2020-09-15T00:00:00", "2020-09-16T00:00:00", "2020-09-17T00:00:00", "2020-09-18T00:00:00", "2020-09-21T00:00:00", "2020-09-22T00:00:00", "2020-09-23T00:00:00", "2020-09-24T00:00:00", "2020-09-25T00:00:00", "2020-09-28T00:00:00", "2020-09-29T00:00:00", "2020-09-30T00:00:00", "2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00", "2020-11-23T00:00:00", "2020-11-24T00:00:00", "2020-11-25T00:00:00", "2020-11-27T00:00:00", "2020-11-30T00:00:00", "2020-12-01T00:00:00", "2020-12-02T00:00:00", "2020-12-03T00:00:00", "2020-12-04T00:00:00", "2020-12-07T00:00:00", "2020-12-08T00:00:00", "2020-12-09T00:00:00", "2020-12-10T00:00:00", "2020-12-11T00:00:00", "2020-12-14T00:00:00", "2020-12-15T00:00:00", "2020-12-16T00:00:00", "2020-12-17T00:00:00", "2020-12-18T00:00:00", "2020-12-21T00:00:00", "2020-12-22T00:00:00", "2020-12-23T00:00:00", "2020-12-24T00:00:00", "2020-12-28T00:00:00", "2020-12-29T00:00:00", "2020-12-30T00:00:00", "2020- ...

# %%
close_data = close_data.reshape((-1))

def predict(num_prediction, model):
    prediction_list = close_data[-look_back:]
    
    for _ in range(num_prediction):
        x = prediction_list[-look_back:]
        x = x.reshape((1, look_back, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[look_back-1:]
        
    return prediction_list
    
def predict_dates(num_prediction):
    last_date = df['Date'].values[-1]
    prediction_dates = pd.date_range(last_date, periods=num_prediction+1).tolist()
    return prediction_dates

num_prediction = 30
forecast = predict(num_prediction, model)
forecast_dates = predict_dates(num_prediction)
