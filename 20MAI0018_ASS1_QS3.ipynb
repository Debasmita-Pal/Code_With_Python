# %% [markdown]
# <a href="https://colab.research.google.com/github/Debasmita-Pal/Single_Layer_Perceptron/blob/main/20MAI0018_ASS1_QS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2

# %%
pet_types = os.listdir('/content/drive/My Drive/Dataset')
print(pet_types)
print("Total types of pets : ",len(pet_types))
# Out:
# ['Dog', 'Cat']
# Total types of pets :  2

# %%
pets = []

for item in pet_types:
  all_pets = os.listdir('/content/drive/My Drive/Dataset' + '/' + item)
  for pet in all_pets:
    pets.append((item, str('/content/drive/My Drive/Dataset' + '/' + item) + '/' + pet))
    print(pets[:1])
# Out:
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# [('Dog', '/content/drive/My Drive/Dataset/Dog/6827.jpg')]
# ...

# %%
#Build a dataframe
pets_df=pd.DataFrame(data=pets, columns=['pet type', 'image'])
print(pets_df.head())
print(pets_df.tail())
# Out:
#   pet type                                         image
# 0      Dog  /content/drive/My Drive/Dataset/Dog/6827.jpg
# 1      Dog  /content/drive/My Drive/Dataset/Dog/6826.jpg
# 2      Dog  /content/drive/My Drive/Dataset/Dog/6805.jpg
# 3      Dog  /content/drive/My Drive/Dataset/Dog/6808.jpg
# 4      Dog  /content/drive/My Drive/Dataset/Dog/6836.jpg
#      pet type                                              image
# 1759      Cat  /content/drive/My Drive/Dataset/Cat/11944 (1).jpg
# 1760      Cat      /content/drive/My Drive/Dataset/Cat/11966.jpg
# 1761      Cat      /content/drive/My Drive/Dataset/Cat/11981.jpg
# 1762      Cat      /content/drive/My Drive/Dataset/Cat/11934.jpg
# 1763      Cat      /content/drive/My Drive/Dataset/Cat/11975.jpg

# %%
print("Total no of pets in the dataset : ", len(pets_df))
pet_count = pets_df['pet type'].value_counts()
print("pets in each category: ")
print(pet_count)
# Out:
# Total no of pets in the dataset :  1764
# pets in each category:
# Cat    888
# Dog    876
# Name: pet type, dtype: int64

# %%
DIRECTORY = '/content/drive/My Drive/Dataset'
CATEGORIES = ['Cat' , 'Dog']

IMG_SIZE = 300

#data = []

for category in CATEGORIES :
  folder = os.path.join(DIRECTORY,category)
  #label = CATEGORIES.index(category)
  for img in os.listdir(folder):
    img_path = os.path.join(folder,img)
    img_arr = cv2.imread(img_path)
    img_arr = cv2.resize(img_arr, (IMG_SIZE,IMG_SIZE))
    #data.append([img_arr, label])
    plt.imshow(img_arr)
    break

# %%
DIRECTORY = '/content/drive/My Drive/Dataset'
CATEGORIES = ['Cat' , 'Dog']

IMG_SIZE = 300

data = []

for category in CATEGORIES :
  folder = os.path.join(DIRECTORY,category)
  label = CATEGORIES.index(category)
  for img in os.listdir(folder):
    img_path = os.path.join(folder,img)
    img_arr = cv2.imread(img_path)
    print(img_arr)
    try:
      img_arr = cv2.resize(img_arr, (IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA)
      print(img_arr.shape)
    except:
      break 
    data.append([img_arr, label])
# Out:
# Streaming output truncated to the last 5000 lines.
#   [106 150 163]
#   [106 150 163]
#   ...
#   [175 199 199]
#   [172 196 196]
#   [170 194 194]]
#
#  [[106 150 163]
#   [106 150 163]
#   [106 150 163]
#   ...
#   [175 199 199]
#   [172 196 196]
#   [170 194 194]]
#
#  [[106 150 163]
#   [106 150 163]
#   [106 150 163]
#   ...
#   [175 199 199]
#   [172 196 196]
#   [170 194 194]]
#
#  ...
#
#  [[ 92 143 159]
#   [ 92 143 159]
#   [ 94 145 161]
#   ...
#   [114  93  71]
#   [113  92  70]
#   [113  92  70]]
#
#  [[ 90 141 157]
#   [ 91 142 158]
#   [ 92 143 159]
#   ...
#   [112  91  69]
#   [111  90  68]
#   [109  88  66]]
#
#  [[ 90 141 157]
#   [ 91 142 158]
#   [ 92 143 159]
#   ...
#   [111  90  68]
#   [109  88  66]
#   [107  86  64]]]
# (300, 300, 3)
# [[[171 190 225]
#   [163 189 226]
#   [167 189 225]
#   ...
#   [203 181 153]
#   [204 182 154]
#   [205 182 156]]
#
#  [[156 174 211]
#   [149 168 213]
#   [153 172 210]
#   ...
#   [202 181 150]
#   [205 181 157]
# ...

# %%
len(data)
# Out:
# 586

# %%
import random
random.shuffle(data)

# %%
data[0]
# Out:
# array([array([[[160, 165, 134],
#         [163, 166, 136],
#         [165, 163, 133],
#         ...,
#         [ 50, 100, 168],
#         [ 47,  94, 163],
#         [ 47,  92, 159]],
#
#        [[161, 166, 135],
#         [164, 167, 136],
#         [165, 164, 134],
#         ...,
#         [ 63, 111, 185],
#         [ 56, 102, 177],
#         [ 53,  96, 170]],
#
#        [[162, 167, 136],
#         [165, 168, 137],
#         [165, 164, 134],
#         ...,
#         [ 77, 124, 204],
#         [ 71, 117, 196],
#         [ 65, 110, 190]],
#
#        ...,
#
#        [[244, 247, 226],
#         [244, 247, 225],
#         [243, 246, 225],
#         ...,
#         [156, 174, 178],
#         [154, 172, 175],
#         [153, 171, 175]],
#
#        [[245, 249, 230],
#         [245, 249, 229],
#         [244, 248, 229],
#         ...,
#         [157, 175, 186],
#         [155, 173, 183],
#         [154, 171, 181]],
#
#        [[245, 249, 230],
#         [245, 249, 230],
# ...

# %%
x = []
y = []
for features, labels in data:
  x.append(features)
  y.append(labels)

# %%
x=np.array(x)
y=np.array(y)

# %%
len(x)
# Out:
# 586

# %%
len(y)
# Out:
# 586

# %%
data = np.array(data)
data.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (586, 2)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
y = pets_df['pet type'].values
print(y[:5])
# Out:
# ['Dog' 'Dog' 'Dog' 'Dog' 'Dog']

# %%
#for y
y_labelencoder = LabelEncoder()
y = y_labelencoder.fit_transform(y)
print(y)
# Out:
# [1 1 1 ... 0 0 0]

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

data,y= shuffle(data,y,random_state=1)
train_x, test_x, train_y, test_y = train_test_split(data, y, test_size=0.3, random_state=415)

#inpect the shape of the training and testing
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (410, 2)
# (410,)
# (176, 2)
# (176,)

# %%
x=x/255
x
# Out:
# array([[[[0.62745098, 0.64705882, 0.5254902 ],
#          [0.63921569, 0.65098039, 0.53333333],
#          [0.64705882, 0.63921569, 0.52156863],
#          ...,
#          [0.19607843, 0.39215686, 0.65882353],
#          [0.18431373, 0.36862745, 0.63921569],
#          [0.18431373, 0.36078431, 0.62352941]],
#
#         [[0.63137255, 0.65098039, 0.52941176],
#          [0.64313725, 0.65490196, 0.53333333],
#          [0.64705882, 0.64313725, 0.5254902 ],
#          ...,
#          [0.24705882, 0.43529412, 0.7254902 ],
#          [0.21960784, 0.4       , 0.69411765],
#          [0.20784314, 0.37647059, 0.66666667]],
#
#         [[0.63529412, 0.65490196, 0.53333333],
#          [0.64705882, 0.65882353, 0.5372549 ],
#          [0.64705882, 0.64313725, 0.5254902 ],
#          ...,
#          [0.30196078, 0.48627451, 0.8       ],
#          [0.27843137, 0.45882353, 0.76862745],
#          [0.25490196, 0.43137255, 0.74509804]],
#
#         ...,
#
# ...

# %%
x.shape
# Out:
# (586, 300, 300, 3)

# %%
#Develop a sequential model using tenserflow keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPooling2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.metrics import confusion_matrix

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())

model.add(Dense(128, input_shape = x.shape[1:], activation = 'relu'))

model.add(Dense(2, activation = 'softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x, y, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 17/17 [==============================] - 122s 7s/step - loss: 5.0200 - accuracy: 0.8542 - val_loss: 1.1052 - val_accuracy: 0.9661
# Epoch 2/5
# 17/17 [==============================] - 102s 6s/step - loss: 1.0046 - accuracy: 0.9724 - val_loss: 0.1199 - val_accuracy: 0.9661
# Epoch 3/5
# 17/17 [==============================] - 101s 6s/step - loss: 0.1479 - accuracy: 0.9718 - val_loss: 0.1339 - val_accuracy: 0.9661
# Epoch 4/5
# 17/17 [==============================] - 101s 6s/step - loss: 0.1342 - accuracy: 0.9751 - val_loss: 0.1524 - val_accuracy: 0.9661
# Epoch 5/5
# 17/17 [==============================] - 97s 6s/step - loss: 0.1288 - accuracy: 0.9741 - val_loss: 0.1443 - val_accuracy: 0.9661
